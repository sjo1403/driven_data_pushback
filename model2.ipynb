# %% [markdown]
# # Read in data

# %%
from datetime import timedelta
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

airports = [
    "KATL",
    "KCLT",
    "KDEN",
    "KDFW",
    "KJFK",
    "KMEM",
    "KMIA",
    "KORD",
    "KPHX",
    "KSEA",
]

# %%
DATA_DIRECTORY = Path("code execution development data/old")

# %% [markdown]
# ## LAMP

# %%
def read_lamp(airport):
    lamp = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_lamp.csv.bz2",
        parse_dates=["timestamp", "forecast_timestamp"],
        dtype={"temperature": "int16", "wind_direction":"int16", "wind_gust":"int16", "cloud_ceiling":"float16", "visibility":"int16"}
    )
    return lamp

# %% [markdown]
# ## TBFM

# %%
def read_tbfm(airport):
    tbfm = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_tbfm.csv.bz2",
        parse_dates=["timestamp", "scheduled_runway_estimated_time"]
    )
    return tbfm

# %% [markdown]
# ## ETD

# %%
def read_etd(airport):
    etd = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_etd.csv.bz2",
        parse_dates=["departure_runway_estimated_time", "timestamp"]
    )
    return etd

# %% [markdown]
# ## MFS

# %%
def read_mfs(airport):
    etd = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_mfs.csv.bz2"
    )
    return etd

# %% [markdown]
# # Initial Model, Linear Regression

# %%
submission_format = pd.read_csv(
    "code execution development data/test_labels.csv", parse_dates=["timestamp"]
)

# %% [markdown]
# ## Insert Data

# %%
def filter_lamp(current_time):
    # weather data
    valid_lamp = lamp.loc[(lamp.timestamp <= current_time) 
                    & (lamp.timestamp > valid_time) 
                    & (lamp.forecast_timestamp <= current_time) 
                    & (lamp.forecast_timestamp > valid_time)]
    return valid_lamp.iloc[-1]
    
def filter_tbfm(current_time):
    # traffic data
    valid_tbfm = tbfm.loc[(tbfm.timestamp <= current_time) 
                    & (tbfm.timestamp > valid_time)]
    return valid_tbfm['gufi'].nunique()
    
def filter_etd(current_time):    
    #etd data
    valid_etd = etd.loc[(etd.timestamp <= current_time) 
                    & (etd.timestamp > valid_time) 
                    & (etd.gufi == df.loc[i].gufi)]
    try:
        return (valid_etd.iloc[-1].departure_runway_estimated_time - current_time).total_seconds()
    except:
        return 3600

# %%
full_frame = pd.DataFrame()
for a in airports:
    airport = a
    df = submission_format[submission_format.airport == a]
    times = df.timestamp.unique()

    etd = read_etd(airport)
    tbfm = read_tbfm(airport)
    lamp = read_lamp(airport)

    for t in times:
        indices = df[df.timestamp == t].index
        current_time = pd.to_datetime(t)
        valid_time = current_time - pd.Timedelta(30, unit='hours')
        
        # insert etd data
        for i in indices:
            df.loc[i, 'etd'] = filter_etd(current_time)
            
        # insert traffic data
        df.loc[indices, 'traffic'] = filter_tbfm(current_time)

        # insert weather data
        current_forecast = filter_lamp(current_time)
        df.loc[indices, 'precip'] = current_forecast.precip
        df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
        df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
        df.loc[indices, 'visibility'] = current_forecast.visibility
        df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
        df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
        df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
        df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
        df.loc[indices, 'temperature'] = current_forecast.temperature
        
    full_frame = pd.concat([full_frame, df])
        
# insert metadata
metadata = pd.concat([read_mfs('KATL'),
                      read_mfs('KCLT'),
                      read_mfs('KDEN'),
                      read_mfs('KDFW'),
                      read_mfs('KJFK'),
                      read_mfs('KMEM'),
                      read_mfs('KMIA'),
                      read_mfs('KORD'),
                      read_mfs('KPHX'),
                      read_mfs('KSEA')])

full_frame = full_frame.merge(metadata, how='left', on='gufi')

full_frame.head(5)
# Out:
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               157513
# timestamp                          157513
# scheduled_runway_estimated_time    157513
# dtype: int64 833
# gufi                               163299
# timestamp                          163299
# scheduled_runway_estimated_time    163299
# dtype: int64 877
# gufi                               156727
# timestamp                          156727
# scheduled_runway_estimated_time    156727
# dtype: int64 808
# gufi                               156657
# timestamp                          156657
# scheduled_runway_estimated_time    156657
# dtype: int64 814
# gufi                               215591
# timestamp                          215591
# scheduled_runway_estimated_time    215591
# dtype: int64 1253
# gufi                               216809
# timestamp                          216809
# scheduled_runway_estimated_time    216809
# dtype: int64 1241
# gufi                               215440
# timestamp                          215440
# scheduled_runway_estimated_time    215440
# dtype: int64 1196
# gufi                               211231
# timestamp                          211231
# scheduled_runway_estimated_time    211231
# dtype: int64 1163
# gufi                               205464
# timestamp                          205464
# scheduled_runway_estimated_time    205464
# dtype: int64 1137
# gufi                               199253
# timestamp                          199253
# scheduled_runway_estimated_time    199253
# dtype: int64 1087
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# gufi                               169984
# timestamp                          169984
# scheduled_runway_estimated_time    169984
# dtype: int64 882
# gufi                               164995
# timestamp                          164995
# scheduled_runway_estimated_time    164995
# dtype: int64 860
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               173540
# timestamp                          173540
# scheduled_runway_estimated_time    173540
# dtype: int64 922
# gufi                               119097
# timestamp                          119097
# scheduled_runway_estimated_time    119097
# dtype: int64 602
# gufi                               126279
# timestamp                          126279
# scheduled_runway_estimated_time    126279
# dtype: int64 643
# gufi                               118390
# timestamp                          118390
# scheduled_runway_estimated_time    118390
# dtype: int64 589
# gufi                               159209
# timestamp                          159209
# scheduled_runway_estimated_time    159209
# dtype: int64 827
# gufi                               152563
# timestamp                          152563
# scheduled_runway_estimated_time    152563
# dtype: int64 796
# gufi                               146057
# timestamp                          146057
# scheduled_runway_estimated_time    146057
# dtype: int64 758
# gufi                               139515
# timestamp                          139515
# scheduled_runway_estimated_time    139515
# dtype: int64 713
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               276137
# timestamp                          276137
# scheduled_runway_estimated_time    276137
# dtype: int64 559
# gufi                               277252
# timestamp                          277252
# scheduled_runway_estimated_time    277252
# dtype: int64 562
# gufi                               425833
# timestamp                          425833
# scheduled_runway_estimated_time    425833
# dtype: int64 968
# gufi                               429352
# timestamp                          429352
# scheduled_runway_estimated_time    429352
# dtype: int64 981
# gufi                               320433
# timestamp                          320433
# scheduled_runway_estimated_time    320433
# dtype: int64 726
# gufi                               309962
# timestamp                          309962
# scheduled_runway_estimated_time    309962
# dtype: int64 666
# gufi                               336025
# timestamp                          336025
# scheduled_runway_estimated_time    336025
# dtype: int64 746
# gufi                               410337
# timestamp                          410337
# scheduled_runway_estimated_time    410337
# dtype: int64 881
# gufi                               398844
# timestamp                          398844
# scheduled_runway_estimated_time    398844
# dtype: int64 865
# gufi                               378336
# timestamp                          378336
# scheduled_runway_estimated_time    378336
# dtype: int64 856
# gufi                               355880
# timestamp                          355880
# scheduled_runway_estimated_time    355880
# dtype: int64 810
# gufi                               421192
# timestamp                          421192
# scheduled_runway_estimated_time    421192
# dtype: int64 937
# gufi                               417185
# timestamp                          417185
# scheduled_runway_estimated_time    417185
# dtype: int64 894
# gufi                               291691
# timestamp                          291691
# scheduled_runway_estimated_time    291691
# dtype: int64 612
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# gufi                               545064
# timestamp                          545064
# scheduled_runway_estimated_time    545064
# dtype: int64 1239
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               536551
# timestamp                          536551
# scheduled_runway_estimated_time    536551
# dtype: int64 1240
# gufi                               518525
# timestamp                          518525
# scheduled_runway_estimated_time    518525
# dtype: int64 1186
# gufi                               504523
# timestamp                          504523
# scheduled_runway_estimated_time    504523
# dtype: int64 1155
# gufi                               489734
# timestamp                          489734
# scheduled_runway_estimated_time    489734
# dtype: int64 1135
# gufi                               377163
# timestamp                          377163
# scheduled_runway_estimated_time    377163
# dtype: int64 799
# gufi                               374273
# timestamp                          374273
# scheduled_runway_estimated_time    374273
# dtype: int64 795
# gufi                               374599
# timestamp                          374599
# scheduled_runway_estimated_time    374599
# dtype: int64 798
# gufi                               373656
# timestamp                          373656
# scheduled_runway_estimated_time    373656
# dtype: int64 794
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               182842
# timestamp                          182842
# scheduled_runway_estimated_time    182842
# dtype: int64 394
# gufi                               181586
# timestamp                          181586
# scheduled_runway_estimated_time    181586
# dtype: int64 384
# gufi                               139652
# timestamp                          139652
# scheduled_runway_estimated_time    139652
# dtype: int64 282
# gufi                               138283
# timestamp                          138283
# scheduled_runway_estimated_time    138283
# dtype: int64 281
# gufi                               137979
# timestamp                          137979
# scheduled_runway_estimated_time    137979
# dtype: int64 285
# gufi                               137813
# timestamp                          137813
# scheduled_runway_estimated_time    137813
# dtype: int64 281
# gufi                               178643
# timestamp                          178643
# scheduled_runway_estimated_time    178643
# dtype: int64 376
# gufi                               175391
# timestamp                          175391
# scheduled_runway_estimated_time    175391
# dtype: int64 367
# gufi                               170684
# timestamp                          170684
# scheduled_runway_estimated_time    170684
# dtype: int64 356
# gufi                               165516
# timestamp                          165516
# scheduled_runway_estimated_time    165516
# dtype: int64 346
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               78377
# timestamp                          78377
# scheduled_runway_estimated_time    78377
# dtype: int64 229
# gufi                               82476
# timestamp                          82476
# scheduled_runway_estimated_time    82476
# dtype: int64 258
# gufi                               121021
# timestamp                          121021
# scheduled_runway_estimated_time    121021
# dtype: int64 356
# gufi                               121986
# timestamp                          121986
# scheduled_runway_estimated_time    121986
# dtype: int64 338
# gufi                               121473
# timestamp                          121473
# scheduled_runway_estimated_time    121473
# dtype: int64 325
# gufi                               119313
# timestamp                          119313
# scheduled_runway_estimated_time    119313
# dtype: int64 321
# gufi                               111456
# timestamp                          111456
# scheduled_runway_estimated_time    111456
# dtype: int64 317
# gufi                               96590
# timestamp                          96590
# scheduled_runway_estimated_time    96590
# dtype: int64 307
# gufi                               121660
# timestamp                          121660
# scheduled_runway_estimated_time    121660
# dtype: int64 339
# gufi                               121958
# timestamp                          121958
# scheduled_runway_estimated_time    121958
# dtype: int64 328
# gufi                               121764
# timestamp                          121764
# scheduled_runway_estimated_time    121764
# dtype: int64 324
# gufi                               122020
# timestamp                          122020
# scheduled_runway_estimated_time    122020
# dtype: int64 330
# gufi                               120141
# timestamp                          120141
# scheduled_runway_estimated_time    120141
# dtype: int64 342
# gufi                               120418
# timestamp                          120418
# scheduled_runway_estimated_time    120418
# dtype: int64 343
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               100431
# timestamp                          100431
# scheduled_runway_estimated_time    100431
# dtype: int64 554
# gufi                               98040
# timestamp                          98040
# scheduled_runway_estimated_time    98040
# dtype: int64 554
# gufi                               100650
# timestamp                          100650
# scheduled_runway_estimated_time    100650
# dtype: int64 560
# gufi                               101043
# timestamp                          101043
# scheduled_runway_estimated_time    101043
# dtype: int64 564
# gufi                               73844
# timestamp                          73844
# scheduled_runway_estimated_time    73844
# dtype: int64 421
# gufi                               75125
# timestamp                          75125
# scheduled_runway_estimated_time    75125
# dtype: int64 424
# gufi                               93988
# timestamp                          93988
# scheduled_runway_estimated_time    93988
# dtype: int64 544
# gufi                               88352
# timestamp                          88352
# scheduled_runway_estimated_time    88352
# dtype: int64 519
# gufi                               83904
# timestamp                          83904
# scheduled_runway_estimated_time    83904
# dtype: int64 495
# gufi                               80400
# timestamp                          80400
# scheduled_runway_estimated_time    80400
# dtype: int64 478
# gufi                               72766
# timestamp                          72766
# scheduled_runway_estimated_time    72766
# dtype: int64 418
# gufi                               73085
# timestamp                          73085
# scheduled_runway_estimated_time    73085
# dtype: int64 420
# gufi                               76928
# timestamp                          76928
# scheduled_runway_estimated_time    76928
# dtype: int64 431
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# gufi                               294221
# timestamp                          294221
# scheduled_runway_estimated_time    294221
# dtype: int64 1003
# gufi                               286747
# timestamp                          286747
# scheduled_runway_estimated_time    286747
# dtype: int64 932
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# gufi                               246448
# timestamp                          246448
# scheduled_runway_estimated_time    246448
# dtype: int64 834
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               255325
# timestamp                          255325
# scheduled_runway_estimated_time    255325
# dtype: int64 639
# gufi                               253798
# timestamp                          253798
# scheduled_runway_estimated_time    253798
# dtype: int64 629
# gufi                               252384
# timestamp                          252384
# scheduled_runway_estimated_time    252384
# dtype: int64 620
# gufi                               201219
# timestamp                          201219
# scheduled_runway_estimated_time    201219
# dtype: int64 496
# gufi                               227027
# timestamp                          227027
# scheduled_runway_estimated_time    227027
# dtype: int64 576
# gufi                               218379
# timestamp                          218379
# scheduled_runway_estimated_time    218379
# dtype: int64 553
# gufi                               179744
# timestamp                          179744
# scheduled_runway_estimated_time    179744
# dtype: int64 404
# gufi                               195732
# timestamp                          195732
# scheduled_runway_estimated_time    195732
# dtype: int64 451
# gufi                               251409
# timestamp                          251409
# scheduled_runway_estimated_time    251409
# dtype: int64 609
# gufi                               254758
# timestamp                          254758
# scheduled_runway_estimated_time    254758
# dtype: int64 634
# gufi                               209458
# timestamp                          209458
# scheduled_runway_estimated_time    209458
# dtype: int64 527
# gufi                               178999
# timestamp                          178999
# scheduled_runway_estimated_time    178999
# dtype: int64 399
# gufi                               184767
# timestamp                          184767
# scheduled_runway_estimated_time    184767
# dtype: int64 423
# gufi                               180799
# timestamp                          180799
# scheduled_runway_estimated_time    180799
# dtype: int64 418
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'etd'] = filter_etd(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'traffic'] = filter_tbfm(current_time)
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'precip'] = current_forecast.precip
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'visibility'] = current_forecast.visibility
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\3381460652.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[indices, 'temperature'] = current_forecast.temperature
# gufi                               241723
# timestamp                          241723
# scheduled_runway_estimated_time    241723
# dtype: int64 592
# gufi                               232722
# timestamp                          232722
# scheduled_runway_estimated_time    232722
# dtype: int64 567
# gufi                               223216
# timestamp                          223216
# scheduled_runway_estimated_time    223216
# dtype: int64 562
# gufi                               252774
# timestamp                          252774
# scheduled_runway_estimated_time    252774
# dtype: int64 644
# gufi                               257336
# timestamp                          257336
# scheduled_runway_estimated_time    257336
# dtype: int64 650
# gufi                               252869
# timestamp                          252869
# scheduled_runway_estimated_time    252869
# dtype: int64 640
# gufi                               251525
# timestamp                          251525
# scheduled_runway_estimated_time    251525
# dtype: int64 626
# gufi                               260314
# timestamp                          260314
# scheduled_runway_estimated_time    260314
# dtype: int64 649
# gufi                               259366
# timestamp                          259366
# scheduled_runway_estimated_time    259366
# dtype: int64 646
# gufi                               255551
# timestamp                          255551
# scheduled_runway_estimated_time    255551
# dtype: int64 625
# gufi                               248999
# timestamp                          248999
# scheduled_runway_estimated_time    248999
# dtype: int64 607
# gufi                               208385
# timestamp                          208385
# scheduled_runway_estimated_time    208385
# dtype: int64 542
# gufi                               194777
# timestamp                          194777
# scheduled_runway_estimated_time    194777
# dtype: int64 524
# gufi                               185512
# timestamp                          185512
# scheduled_runway_estimated_time    185512
# dtype: int64 507
# gufi                               174208
# timestamp                          174208
# scheduled_runway_estimated_time    174208
# dtype: int64 465
# gufi                               172741
# timestamp                          172741
# scheduled_runway_estimated_time    172741
# dtype: int64 452
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\2764470233.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   etd = pd.read_csv(
# C:\Users\Shantel\AppData\Local\Temp\ipykernel_28964\2764470233.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   etd = pd.read_csv(
#                                    gufi           timestamp airport  \
# 0  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 11:15:00    KATL
# 1  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 11:15:00    KATL
# 2  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 12:00:00    KATL
# 3  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 12:00:00    KATL
# 4   AAL153.ATL.CLT.201114.1137.0016.TFM 2020-11-15 10:30:00    KATL
#
#    minutes_until_pushback     etd  traffic precip lightning_prob cloud  \
# 0                      86  6300.0    833.0  False              N    FW
# 1                      86  6300.0    833.0  False              N    FW
# 2                      41  3600.0    877.0  False              N    SC
# 3                      41  3600.0    877.0  False              N    SC
# 4                      62  4980.0    808.0  False              N    SC
#
#    visibility  cloud_ceiling  wind_gust  wind_speed  wind_direction  \
# 0         7.0            8.0        0.0         2.0            13.0
# 1         7.0            8.0        0.0         2.0            13.0
# 2         7.0            8.0        0.0         5.0            14.0
# 3         7.0            8.0        0.0         5.0            14.0
# 4         7.0            8.0        0.0         5.0            11.0
#
#    temperature aircraft_engine_class aircraft_type major_carrier  \
# 0         54.0                   JET          A319           AAL
# 1         54.0                   JET          A319           AAL
# 2         53.0                   JET          A319           AAL
# 3         53.0                   JET          A319           AAL
# 4         53.0                   JET          A320           AAL
#
#                flight_type  isdeparture
# 0  SCHEDULED_AIR_TRANSPORT         True
# 1  SCHEDULED_AIR_TRANSPORT        False
# 2  SCHEDULED_AIR_TRANSPORT         True
# 3  SCHEDULED_AIR_TRANSPORT        False
# 4  SCHEDULED_AIR_TRANSPORT         True

# %% [markdown]
# ## Feature Engineering

# %%
full_frame.nunique()
# Out:
# gufi                                   1228
# timestamp                                17
# minutes_until_pushback                  133
# etd                                     142
# traffic                                 114
#                                        ...
# aircraft_type_MD11                        2
# aircraft_type_PC12                        2
# major_carrier_DAL                         2
# major_carrier_UAL                         2
# flight_type_SCHEDULED_AIR_TRANSPORT       2
# Length: 68, dtype: int64

# %%
# binary encoding
full_frame.replace(False, 0, inplace=True)
full_frame.replace(True, 0, inplace=True)

# %%
# nominal encoding
full_frame = pd.get_dummies(full_frame, columns=['airport',
                                 'cloud', 
                                 'lightning_prob',
                                 'aircraft_engine_class',
                                 'aircraft_type',
                                 'major_carrier',
                                 'flight_type'], 
                    drop_first=True)
full_frame.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 # nominal encoding
# ----> 2 full_frame = pd.get_dummies(full_frame, columns=['airport',
#       3                                  'cloud',
#       4                                  'lightning_prob',
#       5                                  'aircraft_engine_class',
#       6                                  'aircraft_type',
#       7                                  'major_carrier',
#       8                                  'flight_type'],
#       9                     drop_first=True)
#      10 full_frame.head(5)
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\reshape\encoding.py:146, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     144     raise TypeError("Input must be a list-like for parameter `columns`")
#     145 else:
# --> 146     data_to_encode = data[columns]
#     148 # validate prefixes and separator to avoid silently dropping cols
#     149 def check_len(item, name):
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:6173, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     if use_interval_msg:
#    6172         key = list(key)
# -> 6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['airport', 'cloud', 'lightning_prob', 'aircraft_engine_class',\n       'aircraft_type', 'major_carrier', 'flight_type'],\n      dtype='object')] are in the [columns]"

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Model 1

# %%
import statsmodels.api as sm

Y = full_frame['minutes_until_pushback']
X = full_frame.drop(columns=['gufi', 'timestamp', 'minutes_until_pushback'])
X = sm.add_constant(X)

model = sm.OLS(Y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     minutes_until_pushback   R-squared:                       0.581
# Model:                                OLS   Adj. R-squared:                  0.570
# Method:                     Least Squares   F-statistic:                     50.53
# Date:                    Sat, 01 Apr 2023   Prob (F-statistic):               0.00
# Time:                            17:47:45   Log-Likelihood:                -10227.
# No. Observations:                    2356   AIC:                         2.058e+04
# Df Residuals:                        2292   BIC:                         2.095e+04
# Df Model:                              63
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  25.1745     13.242      1.901      0.057      -0.793      51.141
# etd                                     0.0131      0.000     52.505      0.000       0.013       0.014
# traffic                                 0.0041      0.006      0.647      0.517      -0.008       0.016
# precip                              -1.474e-12   8.83e-12     -0.167      0.867   -1.88e-11    1.58e-11
# visibility                              2.5664      0.885      2.900      0.004       0.831       4.302
# cloud_ceiling                          -6.4138      1.307     -4.907      0.000      -8.977      -3.850
# wind_gust                               0.1354      0.163      0.830      0.406      -0.184       0.455
# wind_speed                             -0.4282      0.329     -1.300      0.194      -1.074       0.218
# wind_direction                         -0.1162      0.126     -0.923      0.356      -0.363       0.131
# temperature                             0.2821      0.179      1.578      0.115      -0.068       0.633
# isdeparture                         -4.405e-14   1.56e-13     -0.283      0.777    -3.5e-13    2.62e-13
# airport_KCLT                           -6.3505      2.521     -2.519      0.012     -11.294      -1.407
# airport_KDEN                            9.5061      6.315      1.505      0.132      -2.878      21.891
# airport_KDFW                            1.1239      3.967      0.283      0.777      -6.656       8.904
# airport_KJFK                            6.3374      4.881      1.298      0.194      -3.234      15.909
# airport_KMEM                           16.8457      6.725      2.505      0.012       3.658      30.034
# airport_KMIA                           -0.1095      6.741     -0.016      0.987     -13.329      13.110
# airport_KORD                           -4.6892      4.477     -1.047      0.295     -13.468       4.089
# airport_KPHX                           -6.4235      4.765     -1.348      0.178     -15.768       2.921
# airport_KSEA                           17.4765      4.740      3.687      0.000       8.182      26.771
# cloud_CL                                4.4843      3.525      1.272      0.203      -2.428      11.397
# cloud_FW                                3.0821      1.324      2.327      0.020       0.485       5.679
# cloud_OV                              -17.9941      4.890     -3.680      0.000     -27.583      -8.405
# cloud_SC                                5.0977      1.653      3.083      0.002       1.855       8.340
# lightning_prob_M                       35.8383     11.089      3.232      0.001      14.094      57.583
# lightning_prob_N                       -6.9442      6.257     -1.110      0.267     -19.214       5.325
# aircraft_engine_class_TURBO            -0.5761      5.720     -0.101      0.920     -11.793      10.641
# aircraft_type_A21N                     -5.1674     11.923     -0.433      0.665     -28.549      18.214
# aircraft_type_A306                      2.0316      8.185      0.248      0.804     -14.019      18.083
# aircraft_type_A319                      0.5540      4.448      0.125      0.901      -8.169       9.277
# aircraft_type_A320                     -3.2783      4.480     -0.732      0.464     -12.063       5.507
# aircraft_type_A321                      0.4114      4.263      0.097      0.923      -7.948       8.771
# aircraft_type_A333                    -17.6371     10.394     -1.697      0.090     -38.020       2.746
# aircraft_type_B712                      1.8936      4.876      0.388      0.698      -7.669      11.456
# aircraft_type_B737                      6.4609      4.893      1.321      0.187      -3.133      16.055
# aircraft_type_B738                     -2.0414      4.280     -0.477      0.633     -10.434       6.351
# aircraft_type_B739                     -2.1412      4.386     -0.488      0.625     -10.742       6.459
# aircraft_type_B752                      6.5260      4.838      1.349      0.177      -2.961      16.013
# aircraft_type_B753                      0.4154      6.186      0.067      0.946     -11.716      12.547
# aircraft_type_B763                      5.1046      5.188      0.984      0.325      -5.068      15.278
# aircraft_type_B764                     13.7081      6.554      2.092      0.037       0.856      26.560
# aircraft_type_B772                     -5.3930      5.537     -0.974      0.330     -16.251       5.465
# aircraft_type_B77L                    -12.1974      8.345     -1.462      0.144     -28.561       4.166
# aircraft_type_B77W                    -12.4201      8.292     -1.498      0.134     -28.681       3.841
# aircraft_type_B788                     -9.4370      9.491     -0.994      0.320     -28.049       9.175
# aircraft_type_B789                      1.3908      6.533      0.213      0.831     -11.420      14.202
# aircraft_type_BCS1                     -2.8258     10.393     -0.272      0.786     -23.206      17.555
# aircraft_type_C25A                    -13.0871     19.496     -0.671      0.502     -51.319      25.144
# aircraft_type_C56X                      8.9412     14.267      0.627      0.531     -19.036      36.918
# aircraft_type_CRJ2                     -2.7927      4.585     -0.609      0.543     -11.785       6.199
# aircraft_type_CRJ7                     -4.0197      4.514     -0.891      0.373     -12.871       4.831
# aircraft_type_CRJ9                     -4.1318      4.447     -0.929      0.353     -12.852       4.588
# aircraft_type_DC10                    -11.9484      7.752     -1.541      0.123     -27.150       3.253
# aircraft_type_DH8D                     -0.5711      6.366     -0.090      0.929     -13.054      11.912
# aircraft_type_E135                      1.6942      6.323      0.268      0.789     -10.704      14.093
# aircraft_type_E145                     -7.9578      4.862     -1.637      0.102     -17.493       1.577
# aircraft_type_E170                     -8.7368      4.759     -1.836      0.066     -18.068       0.595
# aircraft_type_E55P                     59.9162     19.543      3.066      0.002      21.593      98.239
# aircraft_type_E75L                     -9.2416      4.547     -2.033      0.042     -18.158      -0.325
# aircraft_type_E75S                     -6.1214      5.128     -1.194      0.233     -16.178       3.935
# aircraft_type_F900                      3.5853     14.317      0.250      0.802     -24.490      31.661
# aircraft_type_MD11                     15.3606      6.110      2.514      0.012       3.378      27.343
# aircraft_type_PC12                     -5.7921     10.718     -0.540      0.589     -26.810      15.226
# major_carrier_DAL                       1.8445      1.488      1.239      0.215      -1.074       4.763
# major_carrier_UAL                       0.2545      1.842      0.138      0.890      -3.358       3.868
# flight_type_SCHEDULED_AIR_TRANSPORT    -4.2431      2.351     -1.805      0.071      -8.853       0.366
# ==============================================================================
# Omnibus:                     2161.112   Durbin-Watson:                   0.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           102163.596
# Skew:                           4.251   Prob(JB):                         0.00
# Kurtosis:                      34.120   Cond. No.                     1.10e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.98e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# calculate MAE
from sklearn.metrics import mean_absolute_error as mae
ypred = model.predict()
MAE = mae(Y, ypred)
MAE
# Out:
# 10.231197185342388

# %%
# check for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

# create VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
vif_data
# Out:
# C:\Users\Shantel\.conda\envs\myenv\lib\site-packages\statsmodels\regression\linear_model.py:1752: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                                 feature          VIF
# 0                                 const  1164.245307
# 1                                   etd     1.108416
# 2                               traffic    21.694123
# 3                                precip          NaN
# 4                            visibility     3.114533
# ..                                  ...          ...
# 61                   aircraft_type_MD11     3.218903
# 62                   aircraft_type_PC12     1.937598
# 63                    major_carrier_DAL     2.733234
# 64                    major_carrier_UAL     2.937714
# 65  flight_type_SCHEDULED_AIR_TRANSPORT     2.667788
#
# [66 rows x 2 columns]

# %% [markdown]
# ## Model 2

# %%
# reduce features
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SequentialFeatureSelector

# re-define independent variables
X = full_frame.drop(columns=['gufi', 'timestamp', 'minutes_until_pushback'])

# linear regression estimator to be used in feature selection
reg = LinearRegression().fit(X, Y)

# %%
# reduce features using SequentialFeatureSelector
sfs = SequentialFeatureSelector(reg, n_features_to_select=20)
sfs.fit(X, Y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), n_features_to_select=20)

# %%
# return selected features
sfs.get_feature_names_out()
# Out:
# array(['etd', 'wind_gust', 'wind_direction', 'airport_KCLT',
#        'airport_KJFK', 'airport_KORD', 'cloud_OV', 'aircraft_type_A21N',
#        'aircraft_type_A320', 'aircraft_type_A333', 'aircraft_type_B752',
#        'aircraft_type_B764', 'aircraft_type_B772', 'aircraft_type_CRJ7',
#        'aircraft_type_CRJ9', 'aircraft_type_E145', 'aircraft_type_E170',
#        'aircraft_type_E75L', 'aircraft_type_PC12',
#        'flight_type_SCHEDULED_AIR_TRANSPORT'], dtype=object)

# %%
# re-fit model
X = full_frame[['etd', 'wind_gust', 'wind_direction', 'airport_KCLT',
       'airport_KJFK', 'airport_KORD', 'cloud_OV', 'aircraft_type_A21N',
       'aircraft_type_A320', 'aircraft_type_A333', 'aircraft_type_B752',
       'aircraft_type_B764', 'aircraft_type_B772', 'aircraft_type_CRJ7',
       'aircraft_type_CRJ9', 'aircraft_type_E145', 'aircraft_type_E170',
       'aircraft_type_E75L', 'aircraft_type_PC12',
       'flight_type_SCHEDULED_AIR_TRANSPORT']]
X = sm.add_constant(X)

model2 = sm.OLS(Y,X).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     minutes_until_pushback   R-squared:                       0.555
# Model:                                OLS   Adj. R-squared:                  0.551
# Method:                     Least Squares   F-statistic:                     145.7
# Date:                    Sat, 01 Apr 2023   Prob (F-statistic):               0.00
# Time:                            17:49:20   Log-Likelihood:                -10299.
# No. Observations:                    2356   AIC:                         2.064e+04
# Df Residuals:                        2335   BIC:                         2.076e+04
# Df Model:                              20
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  14.8173      2.144      6.911      0.000      10.613      19.022
# etd                                     0.0129      0.000     52.852      0.000       0.012       0.013
# wind_gust                               0.0919      0.054      1.701      0.089      -0.014       0.198
# wind_direction                         -0.2298      0.073     -3.152      0.002      -0.373      -0.087
# airport_KCLT                           -6.9866      1.507     -4.637      0.000      -9.942      -4.032
# airport_KJFK                           -4.0936      2.267     -1.806      0.071      -8.538       0.351
# airport_KORD                          -13.2500      1.989     -6.662      0.000     -17.150      -9.350
# cloud_OV                                1.9402      1.241      1.563      0.118      -0.494       4.374
# aircraft_type_A21N                    -12.3662     11.309     -1.094      0.274     -34.543       9.810
# aircraft_type_A320                     -3.2943      1.781     -1.850      0.065      -6.787       0.198
# aircraft_type_A333                    -15.8188      9.663     -1.637      0.102     -34.768       3.131
# aircraft_type_B752                      6.3332      2.365      2.677      0.007       1.695      10.972
# aircraft_type_B764                     14.5395      5.099      2.851      0.004       4.540      24.539
# aircraft_type_B772                     -5.6232      3.670     -1.532      0.126     -12.820       1.573
# aircraft_type_CRJ7                     -5.1740      1.793     -2.885      0.004      -8.690      -1.658
# aircraft_type_CRJ9                     -3.6846      1.611     -2.288      0.022      -6.843      -0.526
# aircraft_type_E145                     -7.6748      2.546     -3.014      0.003     -12.668      -2.682
# aircraft_type_E170                     -8.0362      2.147     -3.742      0.000     -12.247      -3.825
# aircraft_type_E75L                     -7.0269      1.796     -3.912      0.000     -10.549      -3.505
# aircraft_type_PC12                    -11.8829      8.026     -1.481      0.139     -27.622       3.856
# flight_type_SCHEDULED_AIR_TRANSPORT    -9.4999      1.604     -5.924      0.000     -12.644      -6.355
# ==============================================================================
# Omnibus:                     2249.693   Durbin-Watson:                   0.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120549.989
# Skew:                           4.493   Prob(JB):                         0.00
# Kurtosis:                      36.871   Cond. No.                     1.09e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# re-calculate MAE
from sklearn.metrics import mean_absolute_error as mae
ypred = model.predict()
MAE = mae(Y, ypred)
MAE
# Out:
# 10.231197185342388

# %%
# re-check for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

# create VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
vif_data
# Out:
#                                 feature        VIF
# 0                                 const  29.256322
# 1                                   etd   1.015750
# 2                             wind_gust   2.412839
# 3                        wind_direction   2.019255
# 4                          airport_KCLT   1.112467
# 5                          airport_KJFK   1.098348
# 6                          airport_KORD   2.008760
# 7                              cloud_OV   1.761591
# 8                    aircraft_type_A21N   1.035147
# 9                    aircraft_type_A320   1.060267
# 10                   aircraft_type_A333   1.007323
# 11                   aircraft_type_B752   1.069166
# 12                   aircraft_type_B764   1.047002
# 13                   aircraft_type_B772   1.042061
# 14                   aircraft_type_CRJ7   1.066961
# 15                   aircraft_type_CRJ9   1.093428
# 16                   aircraft_type_E145   1.040764
# 17                   aircraft_type_E170   1.055258
# 18                   aircraft_type_E75L   1.116878
# 19                   aircraft_type_PC12   1.041506
# 20  flight_type_SCHEDULED_AIR_TRANSPORT   1.190025
